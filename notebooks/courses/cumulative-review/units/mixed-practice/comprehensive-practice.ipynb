# %% [markdown]
# # Comprehensive practice
#
# A mixed, untimed assessment for integrating methods across the course catalog.
#
# > Canonical lesson: [courses/cumulative-review/units/mixed-practice/comprehensive-practice.qmd](https://freecampus.github.io/math/courses/cumulative-review/units/mixed-practice/comprehensive-practice.html)

# %%
# Generated dependency setup for Colab/Jupyter.
# An existing contributor/CI environment is left unchanged.
import importlib.util
import subprocess
import sys

_required_modules = ('fcmath',)
if any(
    importlib.util.find_spec(name) is None for name in _required_modules
):
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", 'freecampus-math'],
        check=True,
    )

# %% [markdown]
# This assessment is intentionally cumulative. For every solution, state the
# relevant definitions or hypotheses, show a manual argument, and use computation
# only as a separately labeled verification.
#
# ## How to use this assessment
#
# 1. Complete one pass without notes and without a timer.
# 2. Mark confidence before checking any solution.
# 3. Classify each gap as conceptual, procedural, computational, or interpretive.
# 4. Return to the linked course outcomes and retry after spaced review.
#
# ::: {.callout-note}
# ## Assessment status
#
# The infrastructure and scoring model are active. The full comprehensive item
# bank remains in development and will expand during the curriculum content audit.
# :::
