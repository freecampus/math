# %% [markdown]
# # Timed Practice
#
# Build speed only after complete mathematical reasoning is dependable.
#
# > Canonical lesson: [courses/cumulative-review/units/mixed-practice/timed-practice.qmd](https://freecampus.github.io/math/courses/cumulative-review/units/mixed-practice/timed-practice.html)

# %%
# Generated dependency setup for Colab/Jupyter.
# An existing contributor/CI environment is left unchanged.
import importlib.util
import subprocess
import sys

_required_modules = ('fcmath',)
if any(
    importlib.util.find_spec(name) is None for name in _required_modules
):
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", 'freecampus-math'],
        check=True,
    )

# %% [markdown]
# Timed work samples fluency; it does not replace understanding. Choose a mixed
# set, hide feedback until the end, record the time limit before starting, and
# stop when time expires. Review every item afterward, including correct answers
# reached through fragile reasoning.
#
# ::: {.callout-warning}
# Timed results are local practice evidence, not a grade, credential, or prediction
# of performance in another setting.
# :::
