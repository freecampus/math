# %% [markdown]
# # Trigonometric Functions and Graphs
#
# Sine, cosine, amplitude, period, midline, phase shift, and transformations.
#
# > Canonical lesson: [courses/advanced-algebra/units/trigonometry/trig-functions-and-graphs.qmd](https://freecampus.github.io/math/courses/advanced-algebra/units/trigonometry/trig-functions-and-graphs.html)

# %%
# Generated dependency setup for Colab/Jupyter.
# An existing contributor/CI environment is left unchanged.
import importlib.util
import subprocess
import sys

_required_modules = ('fcmath', 'sympy',)
if any(
    importlib.util.find_spec(name) is None for name in _required_modules
):
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", 'freecampus-math', 'sympy>=1.12,<2'],
        check=True,
    )

# %% [markdown]
# As an angle moves around the unit circle, the sine and cosine coordinates move
# up and down in a repeating pattern. When we graph those coordinates against the
# angle, we get waves. These waves model sound, tides, seasons, alternating
# current, vibrations, and many other periodic phenomena.
#
# ::: {.learning-objectives}
# ### Learning objectives
#
# After this lesson you should be able to:
#
# - identify amplitude, period, and midline;
# - sketch the basic sine and cosine graphs;
# - describe vertical shifts and horizontal shifts;
# - interpret the parameters in `y = A sin(B(x-C)) + D`;
# - connect graph features to real periodic situations;
# - use Python and SymPy to inspect trig graphs.
# :::
#
# ## The basic sine graph
#
# The graph of `y = sin(x)` repeats every `2pi` radians.
#
# Important points over one period are:
#
# | `x` | `0` | `pi/2` | `pi` | `3pi/2` | `2pi` |
# |---:|---:|---:|---:|---:|---:|
# | `sin(x)` | `0` | `1` | `0` | `-1` | `0` |
#
# It starts at the midline, rises to a maximum, returns to the midline, falls to a
# minimum, and returns to the midline.
#
# ## The basic cosine graph
#
# The graph of `y = cos(x)` also repeats every `2pi` radians.
#
# Important points are:
#
# | `x` | `0` | `pi/2` | `pi` | `3pi/2` | `2pi` |
# |---:|---:|---:|---:|---:|---:|
# | `cos(x)` | `1` | `0` | `-1` | `0` | `1` |
#
# Cosine starts at a maximum.
#
# ## Amplitude
#
# Amplitude is the distance from the midline to a maximum or minimum. For
#
# ```text
# y = A sin(x)
# ```
#
# amplitude is `|A|`.
#
# Examples:
#
# ```text
# y = 3 sin(x)       amplitude 3
# y = -2 cos(x)      amplitude 2
# ```
#
# A negative coefficient reflects the graph across the midline; amplitude remains
# positive.
#
# ## Period
#
# The period is the horizontal length of one complete cycle.
#
# For
#
# ```text
# y = sin(Bx) or y = cos(Bx)
# ```
#
# the period is:
#
# ::: {.formula-box}
# ```text
# period = 2pi / |B|
# ```
# :::
#
# Example:
#
# ```text
# y = sin(2x) has period pi
# ```
#
# because `2pi/2 = pi`.
#
# ## Midline and vertical shift
#
# For
#
# ```text
# y = A sin(B(x-C)) + D
# ```
#
# the midline is:
#
# ```text
# y = D
# ```
#
# The graph oscillates above and below that line.
#
# ## Phase shift
#
# The value `C` in
#
# ```text
# y = A sin(B(x-C)) + D
# ```
#
# shifts the graph horizontally. The expression `x-C` shifts right by `C`.
#
# ## Worked example: read a graph formula
#
# Analyze:
#
# ```text
# y = 4 sin(2(x - pi/3)) + 1
# ```
#
# 1. Amplitude: `|4| = 4`.
# 2. Period: `2pi / 2 = pi`.
# 3. Midline: `y = 1`.
# 4. Phase shift: right `pi/3`.
#
# The graph ranges from `1-4=-3` to `1+4=5`.
#
# ## Common pitfalls
#
# - Calling the maximum value the amplitude.
# - Forgetting amplitude is always nonnegative.
# - Using `2pi * B` instead of `2pi / |B|` for period.
# - Missing the midline shift.
# - Confusing a right shift with a left shift.
#
# ## Practice exercises
#
# ::: {.practice-box}
# 1. What is the amplitude of `y = -5 cos(x)`?
# 2. What is the period of `y = sin(3x)`?
# 3. What is the midline of `y = 2 sin(x) - 4`?
# 4. Does `y = sin(x - pi/2)` shift left or right?
# 5. What are the maximum and minimum of `y = 3 cos(x) + 2`?
# :::
#
# ::: {.callout-tip collapse="true"}
# ## Solutions
#
# 1. `5`.
# 2. `2pi/3`.
# 3. `y = -4`.
# 4. Right by `pi/2`.
# 5. Maximum `2+3=5`; minimum `2-3=-1`.
# :::
#
# ## Subtopic guided practice and checkpoints
#
# Graph questions become easier when you identify one feature at a time.
#
# ### Lab 1: find amplitude
#
# **Guess first.** Is the amplitude of `y=-7sin(x)` equal to `-7` or `7`?
#
# **Guided exercise.**
#
# Amplitude is distance from the midline, so it cannot be negative:
#
# ```text
# amplitude = |-7| = 7
# ```
#
# ::: {.practice-box}
# **Checkpoint.** Find the amplitude of `y = 0.5 cos(x)`.
# :::
#
# ### Lab 2: find period
#
# **Guess first.** Does `sin(4x)` repeat faster or slower than `sin(x)`?
#
# **Guided exercise.**
#
# Use the formula:
#
# ```text
# period = 2pi / |4| = pi/2
# ```
#
# The graph repeats faster because the period is shorter.
#
# ::: {.practice-box}
# **Checkpoint.** Find the period of `y = cos(x/2)`.
# :::
#
# ### Lab 3: find midline and range
#
# **Guess first.** For `y=2sin(x)+3`, is the midline `y=2` or `y=3`?
#
# **Guided exercise.**
#
# The vertical shift is `+3`, so the midline is `y=3`. The amplitude is 2, so the
# range is:
#
# ```text
# 3 - 2 = 1
# 3 + 2 = 5
# ```
#
# ::: {.practice-box}
# **Checkpoint.** Find the midline and range of `y = 4 cos(x) - 1`.
# :::
#
# ### Lab 4: phase shift
#
# **Guess first.** Does `x - pi` shift right or left?
#
# **Guided exercise.**
#
# Inside subtraction shifts right:
#
# ```text
# y = sin(x - pi) shifts right pi
# ```
#
# ::: {.practice-box}
# **Checkpoint.** Describe the shift of `y = cos(x + pi/4)`.
# :::
#
# ::: {.callout-tip collapse="true"}
# ### Lab checkpoint answers
#
# 1. `0.5`.
# 2. `2pi / |1/2| = 4pi`.
# 3. Midline `y=-1`; range `[-5,3]`.
# 4. Left by `pi/4`.
# :::
#
# ## Trig-graph guessing game
#
#
#
# ### Trigonometric graphs checkpoint: notebook-safe question pool
#
# The website samples this pool dynamically. This deterministic notebook edition preserves every question generator for the selected topic. Try each item before opening its solution.
#
# #### 1. What is the amplitude of y = 3 sin(x)?
#
# **Given:** vertical stretch
#
# - [ ] pi
#
# - [ ] 2pi
#
# - [ ] 3
#
# - [ ] 1
#
# <details><summary>Answer and explanation</summary>
#
# **Answer:** 3
#
# Amplitude is the absolute value of the coefficient in front of sine or cosine.
#
# </details>
#
# #### 2. What is the period of sin(x)?
#
# **Given:** basic sine wave
#
# - [ ] pi
#
# - [ ] 4pi
#
# - [ ] 2pi
#
# - [ ] 1
#
# <details><summary>Answer and explanation</summary>
#
# **Answer:** 2pi
#
# Basic sine repeats every 2pi radians.
#
# </details>
#
# #### 3. What is the midline of y = sin(x) + 4?
#
# **Given:** vertical shift
#
# - [ ] x = 4
#
# - [ ] y = 4
#
# - [ ] y = -4
#
# - [ ] y = 1
#
# <details><summary>Answer and explanation</summary>
#
# **Answer:** y = 4
#
# The +4 shifts the center line to y=4.
#
# </details>
#
# #### 4. In y = sin(x - pi/2), which way is the graph shifted?
#
# **Given:** inside subtraction
#
# - [ ] down
#
# - [ ] right
#
# - [ ] up
#
# - [ ] left
#
# <details><summary>Answer and explanation</summary>
#
# **Answer:** right
#
# Subtracting inside shifts the graph right.
#
# </details>
#
# ## Using this lesson with fcmath and SymPy
#
# Use Python to sample a sine graph.

# %%
import math

xs = [0, math.pi / 2, math.pi, 3 * math.pi / 2, 2 * math.pi]
[(x, math.sin(x)) for x in xs]

# %% [markdown]
# Use SymPy to inspect symbolic period.

# %%
import sympy as sp

x = sp.symbols("x")
sp.periodicity(sp.sin(3 * x), x)
