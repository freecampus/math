# %% [markdown]
# # Guessing Quiz
#
# Interactive algebra guessing quiz.
#
# > Canonical lesson: [courses/advanced-algebra/units/algebra/guessing_quiz.qmd](https://freecampus.github.io/math/courses/advanced-algebra/units/algebra/guessing_quiz.html)

# %%
# Generated dependency setup for Colab/Jupyter.
# An existing contributor/CI environment is left unchanged.
import importlib.util
import subprocess
import sys

_required_modules = ('fcmath',)
if any(
    importlib.util.find_spec(name) is None for name in _required_modules
):
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", 'freecampus-math'],
        check=True,
    )

# %% [markdown]
# This page demonstrates the first interactive algebra quiz in `FreeCampus Math`.
#
# The package also provides a Python notebook widget, but rendered Quarto HTML
# does not keep a live Python kernel after publication. This page uses a
# browser-native version of the quiz so it remains interactive as a static HTML
# document.
#
# ## Guess the expression
#
# Choose the expression that matches the graph.
#
#
#
# ### Graph-to-expression guessing game: notebook-safe question pool
#
# The website samples this pool dynamically. This deterministic notebook edition preserves every question generator for the selected topic. Try each item before opening its solution.
#
# #### 1. Select the expression that matches the graph.
#
# - [ ] -2x² - x
#
# - [ ] -3x² - 2x + 4
#
# - [ ] 3x² + 3
#
# - [ ] 3cos(3x)
#
# <details><summary>Answer and explanation</summary>
#
# **Answer:** -2x² - x
#
# Use shape, intercepts, curvature, and end behavior to eliminate distractors.
#
# </details>
#
# #### 2. Select the function value.
#
# **Given:** f(x) = 4x² + 3x - 4;  find f(0)
#
# - [ ] 0
#
# - [ ] 4
#
# - [ ] -7
#
# - [ ] -4
#
# <details><summary>Answer and explanation</summary>
#
# **Answer:** -4
#
# Substitute the input into every occurrence of x before simplifying.
#
# </details>
#
# ## Python notebook widget
#
# Use this version in a live Jupyter notebook or notebook-style Quarto preview
# with a running Python kernel.
#
# ```python
# from fcmath.algebra import GuessingQuizWidget
#
# quiz = GuessingQuizWidget(total_questions=5)
# quiz.display()
# ```
