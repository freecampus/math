# %% [markdown]
# # Functions and Control Flow
#
# Learn if-statements, loops, and reusable Python functions.
#
# > Canonical lesson: [courses/mathematical-computing/units/python-foundations/functions-and-control-flow.qmd](https://freecampus.github.io/math/courses/mathematical-computing/units/python-foundations/functions-and-control-flow.html)

# %%
# Generated dependency setup for Colab/Jupyter.
# An existing contributor/CI environment is left unchanged.
import importlib.util
import subprocess
import sys

_required_modules = ('fcmath',)
if any(
    importlib.util.find_spec(name) is None for name in _required_modules
):
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", 'freecampus-math'],
        check=True,
    )

# %% [markdown]
# ::: {.learning-objectives}
# ### Learning Objectives
#
# - Use `if`, `elif`, and `else` to make decisions.
# - Use loops to process repeated values.
# - Define reusable functions.
# - Understand why functions make quantitative code easier to maintain.
# :::
#
# ## Motivation
#
# Quantitative Python work often repeats the same logic: classify a value, compute a
# running total, or apply a formula to several inputs. Functions and control flow
# make that logic explicit.
#
# ## Conditional Logic

# %%
value = -2

if value < 0:
    label = "negative"
elif value > 0:
    label = "positive"
else:
    label = "zero"

label

# %% [markdown]
# The package includes a small helper with the same logic.

# %%
from fcmath.python_fundamentals import classify_number

classify_number(-2), classify_number(0), classify_number(5)

# %% [markdown]
# ## Loops
#
# Loops let us process a sequence of values.

# %%
values = [1, 2, 3]
total = 0

for value in values:
    total = total + value

total

# %% [markdown]
# ## Functions
#
# A function gives a name to a reusable computation.

# %%
def simple_interest(principal, rate, years):
    return principal * rate * years

simple_interest(1000, 0.05, 2)

# %% [markdown]
# ## Running Totals

# %%
from fcmath.python_fundamentals import cumulative_sum

cumulative_sum([100, -20, 50, 10])

# %% [markdown]
# ## Common Mistakes
#
# ::: {.common-mistake}
# ### Indentation Is Syntax
#
# Python uses indentation to decide what belongs inside an `if`, loop, or
# function. Misaligned code changes the meaning.
# :::
#
# ::: {.common-mistake}
# ### Forgetting `return`
#
# If a function does not return a value, Python returns `None`.
# :::
#
# ## Practice
#
# ::: {.practice-box}
# 1. Write a function that doubles a number.
# 2. Write an `if` statement that labels a number as "large" if it is above `100`.
# 3. Use a loop to sum `[2, 4, 6, 8]`.
# 4. Use `cumulative_sum` on `[10, -3, 7]`.
# :::
#
# ## Solutions
#
# ::: {.callout-tip collapse="true"}
# ## Solution 1
#
# Answer:
#
# ```python
# def double(value):
#     return 2 * value
# ```
# :::
#
# ::: {.callout-tip collapse="true"}
# ## Solution 2
#
# Answer:
#
# ```python
# if value > 100:
#     label = "large"
# else:
#     label = "not large"
# ```
# :::
#
# ::: {.callout-tip collapse="true"}
# ## Solution 3
#
# Answer: `20`.
#
# ```python
# total = 0
# for value in [2, 4, 6, 8]:
#     total = total + value
# ```
# :::
#
# ::: {.callout-tip collapse="true"}
# ## Solution 4
#
# Answer: `[10, 7, 14]`.
#
# The running totals are `10`, then `10 - 3 = 7`, then `7 + 7 = 14`.
# :::
