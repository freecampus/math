# %% [markdown]
# # NumPy and Arrays
#
# Use NumPy arrays for quantitative calculations.
#
# > Canonical lesson: [courses/mathematical-computing/units/python-foundations/numpy-and-arrays.qmd](https://freecampus.github.io/math/courses/mathematical-computing/units/python-foundations/numpy-and-arrays.html)

# %%
# Generated dependency setup for Colab/Jupyter.
# An existing contributor/CI environment is left unchanged.
import importlib.util
import subprocess
import sys

_required_modules = ('fcmath', 'numpy',)
if any(
    importlib.util.find_spec(name) is None for name in _required_modules
):
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", 'freecampus-math', 'numpy>=1.26,<3'],
        check=True,
    )

# %% [markdown]
# ::: {.learning-objectives}
# ### Learning Objectives
#
# - Create NumPy arrays.
# - Perform vectorized arithmetic.
# - Compute basic summary statistics.
# - Understand why arrays are useful for mathematical modeling.
# :::
#
# ## Motivation
#
# Lists are useful, but quantitative work usually needs fast operations over many
# numbers. NumPy arrays make those operations concise and efficient.
#
# ## Creating Arrays

# %%
import numpy as np

values = np.array([1, 2, 3, 4, 5])
values

# %% [markdown]
# ## Vectorized Arithmetic
#
# When you multiply an array by `2`, NumPy multiplies every element.

# %%
values * 2

# %% [markdown]
# This is different from a Python list:

# %%
[1, 2, 3] * 2

# %% [markdown]
# ## Summary Statistics

# %%
values.mean(), values.min(), values.max(), values.sum()

# %% [markdown]
# The package includes a reusable summary helper.

# %%
from fcmath.python_fundamentals import array_summary

array_summary(values)

# %% [markdown]
# ## Common Mistakes
#
# ::: {.common-mistake}
# ### Expecting Lists and Arrays to Behave the Same Way
#
# `[1, 2, 3] * 2` repeats a list. `np.array([1, 2, 3]) * 2` doubles each value.
# :::
#
# ::: {.common-mistake}
# ### Ignoring Shape
#
# Array shape tells you the dimensions of the data. Many numerical errors come
# from using arrays with incompatible shapes.
# :::
#
# ## Practice
#
# ::: {.practice-box}
# 1. Create an array with values `[10, 20, 30]`.
# 2. Divide every value by `10`.
# 3. Compute the mean.
# 4. Use `array_summary(...)` on the array.
# :::
#
# ## Solutions
#
# ::: {.callout-tip collapse="true"}
# ## Solution 1
#
# Answer:
#
# ```python
# import numpy as np
#
# values = np.array([10, 20, 30])
# ```
# :::
#
# ::: {.callout-tip collapse="true"}
# ## Solution 2
#
# Answer: `array([1., 2., 3.])`.
#
# ```python
# values / 10
# ```
# :::
#
# ::: {.callout-tip collapse="true"}
# ## Solution 3
#
# Answer: `20.0`.
#
# The mean is `(10 + 20 + 30) / 3 = 20`.
# :::
#
# ::: {.callout-tip collapse="true"}
# ## Solution 4
#
# Answer:
#
# ```python
# from fcmath.python_fundamentals import array_summary
#
# array_summary(values)
# ```
# :::
